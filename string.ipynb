# %%
print('Hello world')
# Out:
# Hello world

# %%
s = """hii alll  thi s i s
bullshit all of this requires my attention"""
print(s)
# Out:
# hii alll  thi s i s
# bullshit all of this requires my attention

# %%
s = """god is 
great and good"""
print(s)
# Out:
# god is
# great and good

# %%
s = 'asdnjnafvjnj'

s[4]
# Out:
# 'j'

# %%
s = 'ABCDEFGHTI'
s[8]
# Out:
# 'T'

# %%
s= 'sfnskjhelk'
s[-1]
# Out:
# 'k'

# %%
s='urihndks'
s[-1]
# Out:
# 's'

# %%
s = 'qwerty'
s[:]
# Out:
# 'qwerty'

# %%
s='asdfghjk'
s[:4]
# Out:
# 'asdf'

# %%
s[4:]
# Out:
# 'ghjk'

# %%
s= 'abcdef'
s[::]
# Out:
# 'abcdef'

# %%
s[::-1]
# Out:
# 'fedcba'

# %%
s[::-5]
# Out:
# 'fa'

# %%
s[::-2]
# Out:
# 'fdb'

# %%
s[::-3]
# Out:
# 'fc'

# %%
s = 'ABCDEF'
for char in s:
    print(char)
# Out:
# A
# B
# C
# D
# E
# F

# %%
s = 'aBCDE'
s= 'A' +s[1:]
print(s)
# Out:
# ABCDE

# %%
s = 'ABCD EF'
s1 = 'H' + s[1:]
s2 = s.replace('ABC','abc')
print(s1)
print(s2)
# Out:
# HBCD EF
# abcD EF

# %%
# common functions that can be used

s = 'vfsbhi vsf dsffnunv dffjkn'

len(s)
s.upper()
s.lower()
s.strip()
s.replace('vsf', 'cadfr')
# Out:
# 'vfsbhi cadfr dsffnunv dffjkn'

# %%
s = 'hello'
d = 'world'
print(s + ' ' + d)
# Out:
# hello world

# %%
s * 3
# Out:
# 'hellohellohello'

# %%
name = 'jake'
age = 23

print(f"name {name}, age {23}")
# Out:
# name jake, age 23

# %%
print('ell' in s)
# Out:
# True

# %%
s = " the name {} is good and {} is also good {} ".format('azad',23, 24)
print(s)
# Out:
#  the name azad is good and 23 is also good 24
