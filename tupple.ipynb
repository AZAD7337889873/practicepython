# %%
tup = ()
print(tup)
# Out:
# ()

# %%
tup = ('Geeks', 'like')
print(tup)
# Out:
# ('Geeks', 'like')

# %%
li = [1,2]
tuple(li)
# Out:
# (1, 2)

# %%
tup = tuple('hey')
tup
# Out:
# ('h', 'e', 'y')

# %%
tup = (95,'hey', 7.5, True,{1:2} )
tup
# Out:
# (95, 'hey', 7.5, True, {1: 2})

# %%
t= tuple('azad singh')
print(t[5])
print(t[:6])
print(t[3:7])
# Out:
# s
# ('a', 'z', 'a', 'd', ' ', 's')
# ('d', ' ', 's', 'i')

# %%
t = ('hey', 'how', 'do')
a,b,c =t
print(a) 
print(b)
print(c)
# Out:
# hey
# how
# do

# %%
t2 = (1,2,3,4)
tf = t +t2
tf
# Out:
# ('hey', 'how', 'do', 1, 2, 3, 4)

# %%
t[:-1]
# Out:
# ('hey', 'how')

# %%
t[::-1]
# Out:
# ('do', 'how', 'hey')

# %%
t[-2:-1]
# Out:
# ('how',)

# %%
del t
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 del t
# ----> 2 t
#
# NameError: name 't' is not defined

# %%
tup = (1,2,3,4,5,5,6)
a,b,*c = tup
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# [3, 4, 5, 5, 6]
