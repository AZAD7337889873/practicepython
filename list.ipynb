# %%
a = [1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
b = ['apple', 'banana']
print(b)
# Out:
# ['apple', 'banana']

# %%
a = list((1,2,3,45,'st'))
print(a)
# Out:
# [1, 2, 3, 45, 'st']

# %%
b = list('GEFG')
b
# Out:
# ['G', 'E', 'F', 'G']

# %%
a = [0]*5

# %%
a = [1,2]
a.append(3)
print(a)
# Out:
# [1, 2, 3]

# %%
s = [1,2,3,4]
s.insert(2,41)
print(s)
# Out:
# [1, 2, 41, 3, 4]

# %%
s = [1,2]
print(s)
# Out:
# [1, 2]

# %%
s = [1,2,3]
s.extend([4,5])
print(s)
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [10,20,30]
a[2] = 40
print(a)
# Out:
# [10, 20, 40]

# %%
a = list((1,2,3,4))
a.remove(3)
print(a)
# Out:
# [1, 2, 4]

# %%
a= [1,2,3,4]
a.pop()
print(a)
# Out:
# [1, 2, 3]

# %%
del a[1]
a
# Out:
# [1, 3]

# %%
a.clear()
a
# Out:
# []

# %%
a = [1,2,3,4,5,6]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
a = [[1,2],[3,4]]
print(a[1])
# Out:
# [3, 4]

# %%
a[1][1]
# Out:
# 4
