# %%
s ={10,10,20}
s
# Out:
# {10, 20}

# %%
type(s)
# Out:
# set

# %%
s= set(["a",'b','c'])
print(s)
# Out:
# {'b', 'c', 'a'}

# %%
s= set(['a','b','c', 'd'])
print(s)
# Out:
# {'b', 'c', 'a', 'd'}

# %%
s[1] = 'PythonFinalizationError'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s[1] = 'PythonFinalizationError'
#
# TypeError: 'set' object does not support item assignment

# %%
s = { "geeks", 10,10.6, True}
s
# Out:
# {10, 10.6, True, 'geeks'}

# %%
s = set(['a','b','c'])
print("Normal Set", s)

fs = frozenset(['e','r','t'])
print("frozen set", fs)
# Out:
# Normal Set {'b', 'c', 'a'}
# frozen set frozenset({'r', 't', 'e'})

# %%
s = {"a",'b','c'}
s.add('d')

# %%
s
# Out:
# {'a', 'b', 'c', 'd'}

# %%
a = {'x','y'}
b = {'y','z'}
u = a.union(b)
print(u)
# Out:
# {'x', 'y', 'z'}

# %%
a = {1,2,3,4}
b = {2,3,4,5}
i = a.intersection(b)
print(i)
# Out:
# {2, 3, 4}

# %%
d = a.difference(b)
print(d)
# Out:
# {1}

# %%
s= {1,2,3,4}
s.clear()
print(s)
# Out:
# set()
