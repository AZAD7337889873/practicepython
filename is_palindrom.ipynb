# %%
def ispalin(text):
    text = text.lower()
    rx = re.compile('\W+')
    text = rx.sub('', text).strip()
    return text == text[::-1]
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\azad singh s\AppData\Local\Temp\ipykernel_25692\4039148615.py:3: SyntaxWarning: invalid escape sequence '\W'
#   rx = re.compile('\W+')
