# %%
def longestinterspacesubstring(word,k):
    n = len(word)
    max_start = 0
    max_len = 1
    curr_start = 0
    curr_len = 1
    for i in range(1,n):
        if abs(ord(word[i])-ord(word[i-1]))<=k:
            curr_len +=1
        else:
            if curr_len > max_len:
                max_len = curr_len
                max_start = curr_start
                
            curr_start = i
            curr_len = 1
    if curr_len> max_len:
        max_len = curr_len
        max_start = curr_start
    return word[max_start:max_start+max_len]

# %%
def longestsubstring(word,k):
    n = len(word)
    max_start = 0
    max_len = 1
    curr_start = 0
    curr_len = 1
    for i in range(1,n):
        if abs(ord(word[i])-ord(word[i-1])) <= k:
            curr_len +=1
        else:
            if curr_len > max_len:
                max_len = curr_len
                max_start = curr_start
            curr_start = i
            curr_len = 1
    if curr_len > max_len:
        max_len = curr_len
        max_start = curr_start
    return word[max_start:max_start +max_len]

# %%
print(longestsubstring("hackerrank", 0))
print(longestinterspacesubstring("hackerrank", 0))
# Out:
# rr
# rr
