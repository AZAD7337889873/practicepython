# %%
def product(arr):
    n = len(arr)
    p= [1] * n
    for i in range(n):
        for j in range(n):
            if i!=j:
                p[i] *= arr[j]
    return p

# %%
print(product([3,34,56,6,7]))
# Out:
# [79968, 7056, 4284, 39984, 34272]

# %%
def product(arr):
    n = len(arr)
    p= [1] * n
    for i in range(n):
        for j in range(n):
            if i!=j:
                p[i] *= arr[j]
    return p

if __name__ == "__main__":
    arr = [10, 3, 5, 6, 2]
    res = product(arr)
    print(" ".join(map(str, res)))
# Out:
# 180 600 360 300 900

# %%
print(" ".join(map(str,product([10,3,5,6,2]))))
# Out:
# 180 600 360 300 900

# %%
print(*product([10, 3, 5, 6, 2]))
# Out:
# 180 600 360 300 900

# %%
def prod(arr):
    n = len(arr)
    prefprod = [1]*n
    suffprod = [1]*n
    res = [0]*n
    for i in range(1,n):
        prefprod[i] = arr[i-1]*prefprod[i-1]
    for j in range(n-2,-1,-1):
        suffprod[j] = arr[j+1]*suffprod[j+1]
    for i in range(n):
        res[i] = prefprod[i]*suffprod[i]
    return res

if __name__ == '__main__':
    arr = [10,3,5,6,2]
    res = prod(arr)
    print(res)
# Out:
# [180, 600, 360, 300, 900]

# %%
def prod(arr):
    n = len(arr)
    prefprod = [1]*n
    sufprod = [1]*n
    res = [0]*n
    for  i in range(1,n):
        prefprod[i] = arr[i-1]*prefprod[i-1]
    for j in range(n-2,-1,-1):
        sufprod[i] = arr[j+1] * sufprod[j+1]
    for i in range(n):
        res  = prefprod[i]*sufprod[i]
    return res

# %%
def p(arr):
    n=len(arr)
    pref = [1]*n
    suf = [1]*n
    res = [0]*n
    for i in range(1,n):
        pref[i] = arr[i-1]*pref[i-1]
    for j in range(n-2,-1,-1):
        suf[j] = arr[j+1]*suf[j+1]
    for i in range(n):
        res[i] = pref[i]*suf[i]
    return res

print(p([10,3,5,6,2]))
# Out:
# [180, 600, 360, 300, 900]

# %%
# method new    

def productnew(arr):
    n = len(arr)
    res = [0]*n
    zeros = 0
    idx = -1
    prod = 1
    for i in range(n):
        if arr[i]==0:
            zeros += 1
            idx = i
        else:
            prod *= arr[i]
    if zeros == 0:
        for i in range(n):
            res[i] = prod//arr[i]
    elif zeros == 1:
        res[idx] = prod
        
    return res

productnew([10,3,5,6,2])
# Out:
# [180, 600, 360, 300, 900]
