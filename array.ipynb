# %%
a = [1,'hellow', [3.14,'world']]
a.append(2)
print(a)
# Out:
# [1, 'hellow', [3.14, 'world'], 2]

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a*2)

res = np.array([[1,2],[3,4]])
print(res*2)
# Out:
# [2 4 6 8]
# [[2 4]
#  [6 8]]

# %%
# array stores data in contigous memory locations
# list uses pointer to locate data
# array supports only one data type [numpy]
# list can store different data types simultanouesly

# %%
import array as arr
a = arr.array('i', [1,2,3,4,5])
print(a[0])
a.append(6)
print(a)
# Out:
# 1
# array('i', [1, 2, 3, 4, 5, 6])

# %%
# Typecode	C Type	Python Type	Minimum Size (Bytes)
# 'b'	signed char	int	1
# 'i'	signed int	int	4
# 'f'	float	float	4
# # 'd'	double	float	8

# %%
import array as arr
a = arr.array('i',[1,2,3])
print(a)
# Out:
# array('i', [1, 2, 3])

# %%
print(*a)
# Out:
# 1 2 3

# %%
for i in range(0,3):
    print(a[i], end = "")
# Out:
# 123

# %%
for i in range(0,2):
    print(a[i], end=' ')
# Out:
# 1 2

# %%
a.insert(1,4)

# %%
a
# Out:
# array('i', [1, 4, 2, 3])

# %%
print(*a)
# Out:
# 1 4 2 3

# %%
b = arr.array('i', [1,2,3,4,5])
print(b[3])

c = arr.array('d', [2.4,3,2.4])
print(c)
print(*c)
print(c[2])
# Out:
# 4
# array('d', [2.4, 3.0, 2.4])
# 2.4 3.0 2.4
# 2.4

# %%
b.remove(1)

# %%
b
# Out:
# array('i', [2, 3, 4, 5])

# %%
b.remove(3)

# %%
b
# Out:
# array('i', [2, 4, 5])

# %%
b.pop(1)
b
# Out:
# array('i', [2, 5])

# %%
import array
a = array.array('i', [1, 2, 3, 1, 5])
a.pop(4)
# Out:
# 5

# %%
print(*a)
# Out:
# 1 2 3 1

# %%
res = a[1:3]
print(res)
# Out:
# array('i', [2, 3])

# %%
res = a[2:]
print(res)
# Out:
# array('i', [3, 1])

# %%
# searching
print(*a)
print(a.index(3))
print(a.index(1))
# Out:
# 1 2 3 1
# 2
# 0

# %%
a[2]= 6
print(a)
# Out:
# array('i', [1, 2, 6, 1])

# %%
count = a.count(1)  # number of elements
count
# Out:
# 2

# %%
a.reverse()
a
# Out:
# array('i', [1, 6, 2, 1])

# %%
a.extend([3,4,5,6,7])
a
# Out:
# array('i', [1, 6, 2, 1, 3, 4, 5, 6, 7])
