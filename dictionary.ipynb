# %%
data = {"name": "jake","age":24}
data
# Out:
# {'name': 'jake', 'age': 24}

# %%
a = { "x": 1, "y":2}
a
# Out:
# {'x': 1, 'y': 2}

# %%
a = dict(name = 'sam', age = 20)
a
# Out:
# {'name': 'sam', 'age': 20}

# %%
d = {"name":"azad", "age":20}
d["age"]
# Out:
# 20

# %%
d.get("name")
# Out:
# 'azad'

# %%
del d["age"]

# %%
d
# Out:
# {'name': 'azad'}

# %%
d = {"a":1, "b":2}
val = d.pop("b")
print(val)
print(d)
# Out:
# 2
# {'a': 1}

# %%
d = {"a":"b", "c":"d"}
d.popitem()
# Out:
# ('c', 'd')

# %%
# list 
l = [1,2,4,5]
l.pop()
l
# Out:
# [1, 2, 4]

# %%
d.clear()
d
# Out:
# {}

# %%
d = {"a":1,"b":2}
for key in d.values():
    print(key)
# Out:
# 1
# 2

# %%
# nested once

d = {
    "student": {"name":"sam","age":22},
    "parent": 2
}
d
# Out:
# {'student': {'name': 'sam', 'age': 22}, 'parent': 2}

# %%
print(d["parent"])
print(d["student"]["name"])
# Out:
# 2
# sam

# %%
print(d["student"])
# Out:
# {'name': 'sam', 'age': 22}
